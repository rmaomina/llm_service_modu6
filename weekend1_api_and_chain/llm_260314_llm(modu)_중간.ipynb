# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
import os
from dotenv import load_dotenv
load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

# %%
# chain = prompt | llm | parser
# LCEL : LangChain Expression Language

# %%
# RunnableSequence
# RunnableParallel
# RunnablePassthrough

# %%
from langchain_core.runnables import RunnableParallel

parallel_chain = RunnableParallel(
    summary = ChatPromptTemplate.from_template('{text}를 한 줄로 요약해주세요'),
    keywords = ChatPromptTemplate.from_template('{text}에서 키워드를 3개만 뽑아주세요')
)

# %%
result = parallel_chain.invoke({"text" : "Langchain은 LLM 기반 application 개발 프레임워크입니다."})

# %%
result
# Out:
# {'summary': ChatPromptValue(messages=[HumanMessage(content='Langchain은 LLM 기반 application 개발 프레임워크입니다.를 한 줄로 요약해주세요', additional_kwargs={}, response_metadata={})]),
#  'keywords': ChatPromptValue(messages=[HumanMessage(content='Langchain은 LLM 기반 application 개발 프레임워크입니다.에서 키워드를 3개만 뽑아주세요', additional_kwargs={}, response_metadata={})])}

# %%
llm = ChatOpenAI(model = "gpt-4o-mini")

# %%
# RunnableBranch
from langchain_core.runnables import RunnableBranch


tech_chain =ChatPromptTemplate.from_template('기술지원팀입니다 : {question}')
billing_chain = ChatPromptTemplate.from_template('요금 관리 팀입니다 : {question}')
general_chain = ChatPromptTemplate.from_template('일반 상담 팀입니다 : {question}')

def route_logic(x):
    text = x['question']   # ~~~쓰다가 에러가 났어요
    if( '오류' in text) or ('에러' in text) : 
        return 'technical'
    elif '가격' in text or '요금' in text :
        return 'billing'
    return 'general'

branch = RunnableBranch(
    (lambda x : route_logic(x) == "technical", tech_chain),
    (lambda x : route_logic(x) == "billing", billing_chain),
    general_chain
)

questions = ["프린터 오류가 났습니다", "월 요금이 얼마인가요?", "영업시간 알려주세요"]
for q in questions:
    print(f"Q: {q}\nA: {branch.invoke({'question':q})}\n")
# Out:
# Q: 프린터 오류가 났습니다
# A: messages=[HumanMessage(content='기술지원팀입니다 : 프린터 오류가 났습니다', additional_kwargs={}, response_metadata={})]
#
# Q: 월 요금이 얼마인가요?
# A: messages=[HumanMessage(content='요금 관리 팀입니다 : 월 요금이 얼마인가요?', additional_kwargs={}, response_metadata={})]
#
# Q: 영업시간 알려주세요
# A: messages=[HumanMessage(content='일반 상담 팀입니다 : 영업시간 알려주세요', additional_kwargs={}, response_metadata={})]

# %%
llm.invoke("안녕하세요")
# Out:
# AIMessage(content='안녕하세요! 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 9, 'total_tokens': 19, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_a1681c17ec', 'id': 'chatcmpl-DJ7vZdzyuJc1g29rx2eNlk6frbWUy', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ce9eb-e30b-75a0-a86f-e8389d848388-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 9, 'output_tokens': 10, 'total_tokens': 19, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (6.8.0)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (4.12.0)
# Requirement already satisfied: brotli>=1.1.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.123.4)
# Requirement already satisfied: ffmpy in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (1.0.0)
# Requirement already satisfied: gradio-client==2.2.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (2.2.0)
# Requirement already satisfied: groovy~=0.1 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.36.0)
# Requirement already satisfied: jinja2<4.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (3.0.3)
# Requirement already satisfied: numpy<3.0,>=1.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (2.3.3)
# Requirement already satisfied: orjson~=3.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (3.11.4)
# Requirement already satisfied: packaging in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (25.0)
# Requirement already satisfied: pandas<4.0,>=1.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (2.3.3)
# Requirement already satisfied: pillow<13.0,>=8.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (12.0.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (2.12.5)
# Requirement already satisfied: pydub in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.0.20)
# Requirement already satisfied: pytz>=2017.2 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (2025.2)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (6.0.3)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.50.0)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.20.0)
# Requirement already satisfied: typing-extensions~=4.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (4.15.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio) (0.38.0)
# Requirement already satisfied: fsspec in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from gradio-client==2.2.0->gradio) (2025.10.0)
# Requirement already satisfied: idna>=2.8 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from anyio<5.0,>=3.0->gradio) (3.10)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from fastapi<1.0,>=0.115.2->gradio) (0.0.4)
# Requirement already satisfied: certifi in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from httpx<1.0,>=0.24.1->gradio) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from httpx<1.0,>=0.24.1->gradio) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio) (0.16.0)
# Requirement already satisfied: filelock in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (3.20.0)
# Requirement already satisfied: requests in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.33.5->gradio) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from pandas<4.0,>=1.0->gradio) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from pandas<4.0,>=1.0->gradio) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from pydantic<=3.0,>=2.0->gradio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from pydantic<=3.0,>=2.0->gradio) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from pydantic<=3.0,>=2.0->gradio) (0.4.2)
# Requirement already satisfied: click>=8.0.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from typer<1.0,>=0.12->gradio) (14.2.0)
# Requirement already satisfied: six>=1.5 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages (from requests->huggingface-hub<2.0,>=0.33.5->gradio) (2.3.0)

# %%
import gradio as gr

# %%
demo1.close()
# Out:
# Closing server running on port: 7860

# %%
def greet(name):
    return f"안녕하세요, {name}님"

demo1 = gr.Interface(
    fn = greet,
    inputs = gr.Textbox(label='이름 입력'),
    outputs = gr.Textbox(label = '인사말'),
    title = '인사봇'
)

demo1.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://951566b81a62a54691.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://951566b81a62a54691.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def echo_bot(message, history):
    return f"Echo : {message}"

demo2 = gr.ChatInterface(
    fn = echo_bot,
    title = '에코챗봇',
    examples = ["안녕하세요", "오늘 날씨 어때요", "FAQ 챗봇 테스트"]
)

demo2.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * Running on public URL: https://ccfce9ef6e21b6d50e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ccfce9ef6e21b6d50e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
with gr.Blocks(title = 'custom layout') as demo3:
    gr.Markdown('custom layout demo')
    with gr.Row():
        with gr.Column(scale=2):
            input_text = gr.Textbox(label='질문')
            submit_btn = gr.Button("전송")
        with gr.Column(scale=1):
            category_output = gr.Textbox(label='카테고리')
            
    output_text = gr.Textbox(label='답변')
    
    def process(text):
        cat = "기술" if any(kw in text for kw in ["오류", "설치", "연결"]) else "일반"

        return cat, f"[{cat}] {text}"
    
    submit_btn.click(fn=process, inputs=input_text, outputs=[category_output, output_text])

demo3.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * Running on public URL: https://c22834912fc51cff0c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://c22834912fc51cff0c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
demo3.close()
# Out:
# Closing server running on port: 7862

# %%
llm = ChatOpenAI(model = "gpt-4o-mini")
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

def echo_bot(message, history):
    return f"Echo : {message}"

def chat_with_llm(message, history):
    messages = [SystemMessage(content ="당신은 친절한 한국어 어시스턴트입니다.")]
    for human, ai in history:
        messages.append(HumanMessage(content=human))
        messages.append(AIMessage(content=ai))
    
    messages.append(HumanMessage(content=message))
    return llm.invoke(messages).content
    

demo = gr.ChatInterface(
    fn = chat_with_llm,
    title = 'Chatbot',
    examples = ["안녕하세요", "Python에 대해 알려주세요", "오늘 기분이 좋아요"]
)
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7864
# * Running on public URL: https://79d874a5979dc01037.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://79d874a5979dc01037.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "/home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages/gradio/queueing.py", line 766, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages/gradio/route_utils.py", line 355, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages/gradio/blocks.py", line 2157, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages/gradio/blocks.py", line 1632, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages/gradio/utils.py", line 1009, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages/gradio/chat_interface.py", line 544, in __wrapper
#     return await submit_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages/gradio/chat_interface.py", line 905, in _submit_fn
#     response = await run_sync(self.fn, *inputs, limiter=self.limiter)  # type: ignore
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages/anyio/to_thread.py", line 61, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 2525, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "/home/oncreative/anaconda3/envs/modu/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 986, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3155988/2661288032.py", line 9, in chat_with_llm
#     for human, ai in history:
#         ^^^^^^^^^
# ValueError: too many values to unpack (expected 2)

# %%
faq_data = [
    {"category": "계정", "question": "비밀번호를 잊어버렸습니다. 어떻게 초기화하나요?",
     "answer": "IT 포털(it.company.com)에서 '비밀번호 재설정' 버튼을 클릭하세요. 등록된 이메일로 재설정 링크가 발송됩니다."},
    {"category": "계정", "question": "계정이 잠겼습니다. 어떻게 해제하나요?",
     "answer": "5회 이상 비밀번호를 틀리면 계정이 잠깁니다. IT 헬프데스크(내선 1234)에 연락하세요."},
    {"category": "계정", "question": "신규 계정은 어떻게 만드나요?",
     "answer": "신규 입사자는 인사팀에서 IT팀에 요청합니다. 입사 당일 계정 정보가 이메일로 발송됩니다."},
    {"category": "계정", "question": "2단계 인증(MFA)을 설정하려면?",
     "answer": "IT 포털 > 보안 설정 > MFA 활성화에서 설정합니다. Google Authenticator 앱을 사용하세요."},
]
