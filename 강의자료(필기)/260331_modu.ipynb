# %%
import os
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from typing import List, Dict, Tuple, Any
from dotenv import load_dotenv

from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_core.documents import Document

# 환경변수 로드
load_dotenv()

# 모델 설정
LLM_MODEL = "gpt-4o-mini"
EMBEDDING_MODEL = "text-embedding-3-small"

llm = ChatOpenAI(model=LLM_MODEL)
embeddings = OpenAIEmbeddings(model=EMBEDDING_MODEL)

from langchain_core.messages import HumanMessage, SystemMessage, AIMessage

# %%
documents = [
    {
        "doc_id": "doc_001",
        "title": "트랜스포머 아키텍처",
        "content": "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. "
                   "셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. "
                   "인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다."
    },
    {
        "doc_id": "doc_002",
        "title": "RAG 시스템 개요",
        "content": "RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. "
                   "외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. "
                   "환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다."
    },
    {
        "doc_id": "doc_003",
        "title": "벡터 임베딩과 유사도 검색",
        "content": "벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. "
                   "코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. "
                   "FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다."
    },
    {
        "doc_id": "doc_004",
        "title": "프롬프트 엔지니어링",
        "content": "프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. "
                   "Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. "
                   "시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다."
    },
    {
        "doc_id": "doc_005",
        "title": "파인튜닝과 전이학습",
        "content": "파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. "
                   "LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. "
                   "전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다."
    },
    {
        "doc_id": "doc_006",
        "title": "토큰화와 텍스트 전처리",
        "content": "토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. "
                   "BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. "
                   "한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다."
    },
    {
        "doc_id": "doc_007",
        "title": "LLM 평가 메트릭",
        "content": "LLM 평가에는 자동 메트릭과 인간 평가가 사용됩니다. "
                   "BLEU, ROUGE, BERTScore 등의 자동 메트릭은 참조 답변과의 유사도를 측정합니다. "
                   "LLM-as-Judge 방식은 다른 LLM을 활용하여 품질을 평가하는 최신 접근법입니다."
    },
    {
        "doc_id": "doc_008",
        "title": "청킹 전략",
        "content": "청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. "
                   "고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. "
                   "청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다."
    },
    {
        "doc_id": "doc_009",
        "title": "하이브리드 검색",
        "content": "하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. "
                   "RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. "
                   "키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다."
    },
    {
        "doc_id": "doc_010",
        "title": "멀티모달 AI",
        "content": "멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. "
                   "GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. "
                   "CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다."
    },
]

# %%
for doc in documents:
    print(f" {doc['doc_id']} : {doc['title']}")
# Out:
#  doc_001 : 트랜스포머 아키텍처
#  doc_002 : RAG 시스템 개요
#  doc_003 : 벡터 임베딩과 유사도 검색
#  doc_004 : 프롬프트 엔지니어링
#  doc_005 : 파인튜닝과 전이학습
#  doc_006 : 토큰화와 텍스트 전처리
#  doc_007 : LLM 평가 메트릭
#  doc_008 : 청킹 전략
#  doc_009 : 하이브리드 검색
#  doc_010 : 멀티모달 AI

# %%
qa_dataset = [
    {
        "query_id": "q01",
        "question": "트랜스포머의 핵심 메커니즘은 무엇인가요?",
        "relevant_doc_ids": ["doc_001"],
        "ground_truth": "트랜스포머의 핵심 메커니즘은 셀프 어텐션으로, 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다."
    },
    {
        "query_id": "q02",
        "question": "RAG 시스템의 장점은 무엇인가요?",
        "relevant_doc_ids": ["doc_002"],
        "ground_truth": "RAG는 환각을 줄이고 최신 정보를 반영할 수 있으며, 외부 지식 베이스를 활용하여 더 정확한 답변을 생성합니다."
    },
    {
        "query_id": "q03",
        "question": "벡터 유사도 검색에 사용되는 데이터베이스는?",
        "relevant_doc_ids": ["doc_003"],
        "ground_truth": "FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 벡터 유사도 검색에 활용됩니다."
    },
    {
        "query_id": "q04",
        "question": "프롬프트 엔지니어링의 주요 기법은?",
        "relevant_doc_ids": ["doc_004"],
        "ground_truth": "Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있으며, 시스템/사용자 프롬프트를 구분합니다."
    },
    {
        "query_id": "q05",
        "question": "효율적 파인튜닝 기법에는 어떤 것이 있나요?",
        "relevant_doc_ids": ["doc_005"],
        "ground_truth": "LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다."
    },
    {
        "query_id": "q06",
        "question": "한국어 토큰화에 적합한 방법은?",
        "relevant_doc_ids": ["doc_006"],
        "ground_truth": "한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다."
    },
    {
        "query_id": "q07",
        "question": "LLM-as-Judge란 무엇인가요?",
        "relevant_doc_ids": ["doc_007"],
        "ground_truth": "LLM-as-Judge는 다른 LLM을 활용하여 생성 품질을 평가하는 최신 접근법입니다."
    },
    {
        "query_id": "q08",
        "question": "적절한 청크 크기는 얼마인가요?",
        "relevant_doc_ids": ["doc_008"],
        "ground_truth": "보통 500-1000 토큰 크기를 사용하며, 청크 크기와 오버랩이 검색 품질에 큰 영향을 미칩니다."
    },
    {
        "query_id": "q09",
        "question": "하이브리드 검색에서 결과를 병합하는 방법은?",
        "relevant_doc_ids": ["doc_009"],
        "ground_truth": "RRF(Reciprocal Rank Fusion)를 통해 키워드 검색과 벡터 검색 결과를 효과적으로 병합합니다."
    },
    {
        "query_id": "q10",
        "question": "검색과 생성을 결합하여 환각을 줄이는 기법은?",
        "relevant_doc_ids": ["doc_002", "doc_003"],
        "ground_truth": "RAG(Retrieval-Augmented Generation)는 검색으로 관련 문서를 찾고 LLM이 이를 기반으로 답변을 생성하여 환각을 줄입니다."
    },
    {
        "query_id": "q11",
        "question": "CLIP 모델의 활용 분야는?",
        "relevant_doc_ids": ["doc_010"],
        "ground_truth": "CLIP은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다."
    },
    {
        "query_id": "q12",
        "question": "트랜스포머의 구조는 어떻게 되어있나요?",
        "relevant_doc_ids": ["doc_001"],
        "ground_truth": "인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다."
    },
]

# %%
for qa in qa_dataset[:5]:
    print(f" {qa['query_id']}: {qa['question'][:40]} ---> {qa['relevant_doc_ids']}")
# Out:
#  q01: 트랜스포머의 핵심 메커니즘은 무엇인가요? ---> ['doc_001']
#  q02: RAG 시스템의 장점은 무엇인가요? ---> ['doc_002']
#  q03: 벡터 유사도 검색에 사용되는 데이터베이스는? ---> ['doc_003']
#  q04: 프롬프트 엔지니어링의 주요 기법은? ---> ['doc_004']
#  q05: 효율적 파인튜닝 기법에는 어떤 것이 있나요? ---> ['doc_005']

# %%
embeddings = OpenAIEmbeddings(model = EMBEDDING_MODEL)
langchain_docs = [
    Document(
        page_content = doc['content'],
        metadata = {"doc_id" : doc['doc_id'], 'title' : doc['title']}
    ) for doc in documents
]

vectorstore = FAISS.from_documents(langchain_docs, embeddings)

# %%
vectorstore.index.ntotal
# Out:
# 12

# %%
def search_documents(query, k):
    results = vectorstore.similarity_search_with_score(query, k=k)
    retrieved = []
    for doc, score in results:
        retrieved.append({
            'doc_id' : doc.metadata['doc_id'],
            'title' : doc.metadata['title'],
            'content' : doc.page_content,
            'score' : float(score)
        })
    
    return retrieved

# %%
search_results_cache = {}
for qa in qa_dataset:
    results = search_documents(qa['question'], k=5)
    search_results_cache[qa['query_id']] = results

# %%
search_results_cache
# Out:
# {'q01': [{'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 0.8692044019699097},
#   {'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.3324843645095825},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.4282066822052002},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.5080897808074951},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.5182702541351318}],
#  'q02': [{'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.1555323600769043},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.5726306438446045},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.5868868827819824},
#   {'doc_id': 'doc_007',
#    'title': 'LLM 평가 메트릭',
#    'content': 'LLM 평가에는 자동 메트릭과 인간 평가가 사용됩니다. BLEU, ROUGE, BERTScore 등의 자동 메트릭은 참조 답변과의 유사도를 측정합니다. LLM-as-Judge 방식은 다른 LLM을 활용하여 품질을 평가하는 최신 접근법입니다.',
#    'score': 1.6015925407409668},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.6117979288101196}],
#  'q03': [{'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 0.6620954871177673},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.3740274906158447},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.470097303390503},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.4794965982437134},
#   {'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.5106784105300903}],
#  'q04': [{'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 0.6668245196342468},
#   {'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 1.4020938873291016},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.4466068744659424},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.4769775867462158},
#   {'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.51665198802948}],
#  'q05': [{'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 0.951934814453125},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.3506778478622437},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.4429908990859985},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.4430904388427734},
#   {'doc_id': 'doc_007',
#    'title': 'LLM 평가 메트릭',
#    'content': 'LLM 평가에는 자동 메트릭과 인간 평가가 사용됩니다. BLEU, ROUGE, BERTScore 등의 자동 메트릭은 참조 답변과의 유사도를 측정합니다. LLM-as-Judge 방식은 다른 LLM을 활용하여 품질을 평가하는 최신 접근법입니다.',
#    'score': 1.493098258972168}],
#  'q06': [{'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 0.7867134809494019},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.3559958934783936},
#   {'doc_id': 'doc_008',
#    'title': '청킹 전략',
#    'content': '청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. 고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. 청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다.',
#    'score': 1.3698420524597168},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.3982272148132324},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.4197537899017334}],
#  'q07': [{'doc_id': 'doc_007',
#    'title': 'LLM 평가 메트릭',
#    'content': 'LLM 평가에는 자동 메트릭과 인간 평가가 사용됩니다. BLEU, ROUGE, BERTScore 등의 자동 메트릭은 참조 답변과의 유사도를 측정합니다. LLM-as-Judge 방식은 다른 LLM을 활용하여 품질을 평가하는 최신 접근법입니다.',
#    'score': 0.7199721336364746},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.3401694297790527},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.416475534439087},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.653063416481018},
#   {'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.7213808298110962}],
#  'q08': [{'doc_id': 'doc_008',
#    'title': '청킹 전략',
#    'content': '청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. 고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. 청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다.',
#    'score': 0.9776157140731812},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.4967402219772339},
#   {'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 1.6112732887268066},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.6966402530670166},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.7224171161651611}],
#  'q09': [{'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 0.635026216506958},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.1824309825897217},
#   {'doc_id': 'doc_008',
#    'title': '청킹 전략',
#    'content': '청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. 고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. 청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다.',
#    'score': 1.395355224609375},
#   {'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 1.459870457649231},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.509538173675537}],
#  'q10': [{'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 0.8623470067977905},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.11051344871521},
#   {'doc_id': 'doc_008',
#    'title': '청킹 전략',
#    'content': '청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. 고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. 청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다.',
#    'score': 1.3884958028793335},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.449475646018982},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.458343744277954}],
#  'q11': [{'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.1070890426635742},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.365318775177002},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.4046611785888672},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.4207402467727661},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.5074043273925781}],
#  'q12': [{'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 1.0377447605133057},
#   {'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.4973644018173218},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.6441315412521362},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.6683160066604614},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.6722891330718994}]}

# %%
sample_q = qa_dataset[3]
sample_q
# Out:
# {'query_id': 'q04',
#  'question': '프롬프트 엔지니어링의 주요 기법은?',
#  'relevant_doc_ids': ['doc_004'],
#  'ground_truth': 'Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있으며, 시스템/사용자 프롬프트를 구분합니다.'}

# %%
search_results_cache[sample_q['query_id']]
# Out:
# [{'doc_id': 'doc_004',
#   'title': '프롬프트 엔지니어링',
#   'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#   'score': 0.6668245196342468},
#  {'doc_id': 'doc_001',
#   'title': '트랜스포머 아키텍처',
#   'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#   'score': 1.4020938873291016},
#  {'doc_id': 'doc_005',
#   'title': '파인튜닝과 전이학습',
#   'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#   'score': 1.4466068744659424},
#  {'doc_id': 'doc_002',
#   'title': 'RAG 시스템 개요',
#   'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#   'score': 1.4769775867462158},
#  {'doc_id': 'doc_010',
#   'title': '멀티모달 AI',
#   'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#   'score': 1.51665198802948}]

# %%
for i, r in enumerate(search_results_cache[sample_q['query_id']]):
    print(f" {i+1}, {r['doc_id']}, {r['title']}")
# Out:
#  1, doc_004, 프롬프트 엔지니어링
#  2, doc_001, 트랜스포머 아키텍처
#  3, doc_005, 파인튜닝과 전이학습
#  4, doc_002, RAG 시스템 개요
#  5, doc_010, 멀티모달 AI

# %%
new_documents = [
    {
        "doc_id": "doc_011",
        "title": "어텐션 메커니즘의 변형",
        "content": "어텐션 메커니즘에는 다양한 변형이 있습니다. "
                   "Flash Attention은 메모리 효율적인 어텐션 계산을 제공하며, "
                   "Sparse Attention은 긴 시퀀스 처리에 효과적입니다."
    },
    {
        "doc_id": "doc_012",
        "title": "LLM 양자화 기법",
        "content": "양자화는 모델의 가중치를 낮은 비트로 표현하여 메모리와 연산을 줄이는 기법입니다. "
                   "GPTQ, AWQ, GGUF 등의 포맷이 있으며, 4비트 양자화가 널리 사용됩니다."
    }
]

new_qa_pairs = [
    {
        "query_id": "q13",
        "question": "메모리 효율적인 어텐션 방법은?",
        "relevant_doc_ids": ["doc_011", "doc_001"],
        "ground_truth": "Flash Attention은 메모리 효율적인 어텐션 계산을 제공합니다."
    },
    {
        "query_id": "q14",
        "question": "LLM 모델 크기를 줄이는 양자화 포맷은?",
        "relevant_doc_ids": ["doc_012"],
        "ground_truth": "GPTQ, AWQ, GGUF 등의 양자화 포맷이 있으며 4비트 양자화가 널리 사용됩니다."
    }
]

# %%
all_docs = documents + new_documents
all_qa = qa_dataset + new_qa_pairs
search_results_cache = {}
for qa in all_qa:
    results = search_documents(qa['question'], k=5)
    search_results_cache[qa['query_id']] = results

# %%
def validate_dataset(docs, qa_pairs):
    #  qa_pairs[q_id] 문서가 docs 있다면 True, 없다면 False
    doc_ids = {d['doc_id'] for d in docs}
    errors = []
    for qa in qa_pairs:
        for rid in qa['relevant_doc_ids']:
            if rid not in doc_ids:
                errors.append(f"{qa['query_id']} : {rid} 문서 없음")
    
    if errors:
        print(f"오류")
    
    else:
        print(f"통과")
    return len(errors)

# %%
validate_dataset(all_docs, all_qa)
# Out:
# 통과
# 0

# %%
# 검색결과에 relevant id 가 나오면 pass, 안나오면 fail
# hitrate
# (1, 2, 3, 4, 5)  1
# (1)              1
# (1,      100)    1
# hitrate@K

# %%
search_results_cache = {}
for qa in all_qa:
    results = search_documents(qa['question'], k=5)
    search_results_cache[qa['query_id']] = results

# %%
def hit_rate_at_k(query_id, k):
    qa_list = [q for q in qa_dataset if q['query_id'] == query_id]
# #     print(qa_list)
#     qa = qa_list[0] if qa_list else None

    qa = next(q for q in qa_dataset if q['query_id'] == query_id)
    
    relevant_ids = set(qa['relevant_doc_ids'])
    retrieved = search_results_cache[query_id][:k]
    retrieved_ids = {r['doc_id'] for r in retrieved}
    
    return 1 if relevant_ids & retrieved_ids else 0

# %%
def average_hit_rate_at_k(k):
    hits = [hit_rate_at_k(qa['query_id'], k) for qa in qa_dataset] # hits = [1, 0, 1, 0, ....]
    return sum(hits)/ len(hits)

# %%
qa['query_id']
# Out:
# 'q12'

# %%
search_results_cache[qa['query_id']][:3]
# Out:
# [{'doc_id': 'doc_001',
#   'title': '트랜스포머 아키텍처',
#   'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#   'score': 1.0304818153381348},
#  {'doc_id': 'doc_010',
#   'title': '멀티모달 AI',
#   'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#   'score': 1.497434377670288},
#  {'doc_id': 'doc_004',
#   'title': '프롬프트 엔지니어링',
#   'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#   'score': 1.6440376043319702}]

# %%
for qa in qa_dataset:
    hit = hit_rate_at_k(qa['query_id'], k=3)
    retrieved_ids = [r['doc_id'] for r in search_results_cache[qa['query_id']][:3]]
#     print(retrieved_ids)
    status = 'HIT' if hit else 'MISS'
    print(f"[{status}] {qa['query_id']}: 정답 = {qa['relevant_doc_ids']} | 검색 = {retrieved_ids}")
# Out:
# [HIT] q01: 정답 = ['doc_001'] | 검색 = ['doc_001', 'doc_010', 'doc_005']
# [HIT] q02: 정답 = ['doc_002'] | 검색 = ['doc_002', 'doc_004', 'doc_009']
# [HIT] q03: 정답 = ['doc_003'] | 검색 = ['doc_003', 'doc_009', 'doc_012']
# [HIT] q04: 정답 = ['doc_004'] | 검색 = ['doc_004', 'doc_001', 'doc_005']
# [HIT] q05: 정답 = ['doc_005'] | 검색 = ['doc_005', 'doc_003', 'doc_011']
# [HIT] q06: 정답 = ['doc_006'] | 검색 = ['doc_006', 'doc_009', 'doc_008']
# [HIT] q07: 정답 = ['doc_007'] | 검색 = ['doc_007', 'doc_004', 'doc_002']
# [HIT] q08: 정답 = ['doc_008'] | 검색 = ['doc_008', 'doc_003', 'doc_001']
# [HIT] q09: 정답 = ['doc_009'] | 검색 = ['doc_009', 'doc_002', 'doc_008']
# [HIT] q10: 정답 = ['doc_002', 'doc_003'] | 검색 = ['doc_002', 'doc_009', 'doc_008']
# [HIT] q11: 정답 = ['doc_010'] | 검색 = ['doc_010', 'doc_005', 'doc_006']
# [HIT] q12: 정답 = ['doc_001'] | 검색 = ['doc_001', 'doc_010', 'doc_004']

# %%
new_qa = [
    {"query_id": "q13", "question": "Flash Attention의 장점은?",
     "relevant_doc_ids": ["doc_001"],
     "ground_truth": "Flash Attention은 메모리 효율적인 어텐션 계산을 제공합니다."},
    {"query_id": "q14", "question": "양자화로 모델 크기를 줄이는 방법은?",
     "relevant_doc_ids": ["doc_005"],
     "ground_truth": "LoRA, QLoRA 등의 효율적 파인튜닝과 양자화 기법으로 모델 크기를 줄입니다."},
    {"query_id": "q15", "question": "RAG에서 청크 크기가 검색에 미치는 영향은?",
     "relevant_doc_ids": ["doc_008", "doc_002"],
     "ground_truth": "청크 크기는 검색 품질에 큰 영향을 미치며 보통 500-1000 토큰을 사용합니다."},
]

# %%
for qa in new_qa:
    search_results_cache[qa['query_id']] = search_documents(qa['question'], k=5)

# %%
search_results_cache
# Out:
# {'q01': [{'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 0.8629994988441467},
#   {'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.3324825763702393},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.4281699657440186},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.5083041191101074},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.5181101560592651}],
#  'q02': [{'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.1562427282333374},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.572098970413208},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.5868675708770752},
#   {'doc_id': 'doc_007',
#    'title': 'LLM 평가 메트릭',
#    'content': 'LLM 평가에는 자동 메트릭과 인간 평가가 사용됩니다. BLEU, ROUGE, BERTScore 등의 자동 메트릭은 참조 답변과의 유사도를 측정합니다. LLM-as-Judge 방식은 다른 LLM을 활용하여 품질을 평가하는 최신 접근법입니다.',
#    'score': 1.6027817726135254},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.6118906736373901}],
#  'q03': [{'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 0.6622857451438904},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.3742742538452148},
#   {'doc_id': 'doc_012',
#    'title': 'LLM 양자화 기법',
#    'content': '양자화는 모델의 가중치를 낮은 비트로 표현하여 메모리와 연산을 줄이는 기법입니다. GPTQ, AWQ, GGUF 등의 포맷이 있으며, 4비트 양자화가 널리 사용됩니다.',
#    'score': 1.4439845085144043},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.4702379703521729},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.4804279804229736}],
#  'q04': [{'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 0.666822075843811},
#   {'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 1.4115067720413208},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.4466197490692139},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.4778339862823486},
#   {'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.5166290998458862}],
#  'q05': [{'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 0.9517742395401001},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.3505034446716309},
#   {'doc_id': 'doc_011',
#    'title': '어텐션 메커니즘의 변형',
#    'content': '어텐션 메커니즘에는 다양한 변형이 있습니다. Flash Attention은 메모리 효율적인 어텐션 계산을 제공하며, Sparse Attention은 긴 시퀀스 처리에 효과적입니다.',
#    'score': 1.419328212738037},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.4427061080932617},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.4427409172058105}],
#  'q06': [{'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 0.7870199680328369},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.3562688827514648},
#   {'doc_id': 'doc_008',
#    'title': '청킹 전략',
#    'content': '청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. 고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. 청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다.',
#    'score': 1.3688522577285767},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.3989349603652954},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.4198780059814453}],
#  'q07': [{'doc_id': 'doc_007',
#    'title': 'LLM 평가 메트릭',
#    'content': 'LLM 평가에는 자동 메트릭과 인간 평가가 사용됩니다. BLEU, ROUGE, BERTScore 등의 자동 메트릭은 참조 답변과의 유사도를 측정합니다. LLM-as-Judge 방식은 다른 LLM을 활용하여 품질을 평가하는 최신 접근법입니다.',
#    'score': 0.716439425945282},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.3399326801300049},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.4177175760269165},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.6531455516815186},
#   {'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.7214765548706055}],
#  'q08': [{'doc_id': 'doc_008',
#    'title': '청킹 전략',
#    'content': '청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. 고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. 청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다.',
#    'score': 0.977252721786499},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.4968936443328857},
#   {'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 1.6100361347198486},
#   {'doc_id': 'doc_012',
#    'title': 'LLM 양자화 기법',
#    'content': '양자화는 모델의 가중치를 낮은 비트로 표현하여 메모리와 연산을 줄이는 기법입니다. GPTQ, AWQ, GGUF 등의 포맷이 있으며, 4비트 양자화가 널리 사용됩니다.',
#    'score': 1.6309013366699219},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.6968419551849365}],
#  'q09': [{'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 0.6353545188903809},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.1829988956451416},
#   {'doc_id': 'doc_008',
#    'title': '청킹 전략',
#    'content': '청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. 고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. 청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다.',
#    'score': 1.3944149017333984},
#   {'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 1.443454384803772},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.5098357200622559}],
#  'q10': [{'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 0.8628339767456055},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.1105036735534668},
#   {'doc_id': 'doc_008',
#    'title': '청킹 전략',
#    'content': '청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. 고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. 청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다.',
#    'score': 1.3872946500778198},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.4494295120239258},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.4585964679718018}],
#  'q11': [{'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.1074365377426147},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.3660387992858887},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.40532648563385},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.421010136604309},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.508303165435791}],
#  'q12': [{'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 1.0304818153381348},
#   {'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.497434377670288},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.6440376043319702},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.6685686111450195},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.6723742485046387}],
#  'q13': [{'doc_id': 'doc_011',
#    'title': '어텐션 메커니즘의 변형',
#    'content': '어텐션 메커니즘에는 다양한 변형이 있습니다. Flash Attention은 메모리 효율적인 어텐션 계산을 제공하며, Sparse Attention은 긴 시퀀스 처리에 효과적입니다.',
#    'score': 1.0368719100952148},
#   {'doc_id': 'doc_004',
#    'title': '프롬프트 엔지니어링',
#    'content': '프롬프트 엔지니어링은 LLM에게 효과적인 지시를 설계하는 기술입니다. Few-shot, Chain-of-Thought, Zero-shot 등의 기법이 있습니다. 시스템 프롬프트와 사용자 프롬프트를 구분하여 역할과 지시를 명확히 합니다.',
#    'score': 1.5250803232192993},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.5453522205352783},
#   {'doc_id': 'doc_001',
#    'title': '트랜스포머 아키텍처',
#    'content': "트랜스포머는 2017년 'Attention is All You Need' 논문에서 제안된 아키텍처입니다. 셀프 어텐션 메커니즘을 사용하여 입력 시퀀스의 모든 위치 간 관계를 병렬로 처리합니다. 인코더-디코더 구조로 구성되며, 멀티헤드 어텐션과 피드포워드 네트워크가 핵심 구성요소입니다.",
#    'score': 1.5477460622787476},
#   {'doc_id': 'doc_012',
#    'title': 'LLM 양자화 기법',
#    'content': '양자화는 모델의 가중치를 낮은 비트로 표현하여 메모리와 연산을 줄이는 기법입니다. GPTQ, AWQ, GGUF 등의 포맷이 있으며, 4비트 양자화가 널리 사용됩니다.',
#    'score': 1.565917730331421}],
#  'q14': [{'doc_id': 'doc_012',
#    'title': 'LLM 양자화 기법',
#    'content': '양자화는 모델의 가중치를 낮은 비트로 표현하여 메모리와 연산을 줄이는 기법입니다. GPTQ, AWQ, GGUF 등의 포맷이 있으며, 4비트 양자화가 널리 사용됩니다.',
#    'score': 1.0257271528244019},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.4143469333648682},
#   {'doc_id': 'doc_005',
#    'title': '파인튜닝과 전이학습',
#    'content': '파인튜닝은 사전 학습된 모델을 특정 태스크에 맞게 추가 학습시키는 기법입니다. LoRA, QLoRA 등의 효율적 파인튜닝 기법이 대형 모델 적응에 널리 사용됩니다. 전이학습을 통해 적은 데이터로도 높은 성능을 달성할 수 있습니다.',
#    'score': 1.4388190507888794},
#   {'doc_id': 'doc_008',
#    'title': '청킹 전략',
#    'content': '청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. 고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. 청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다.',
#    'score': 1.4933830499649048},
#   {'doc_id': 'doc_010',
#    'title': '멀티모달 AI',
#    'content': '멀티모달 AI는 텍스트, 이미지, 오디오 등 다양한 데이터 유형을 처리합니다. GPT-4V, Gemini 등이 대표적인 멀티모달 모델입니다. CLIP 모델은 이미지-텍스트 쌍을 학습하여 크로스모달 검색에 활용됩니다.',
#    'score': 1.5387303829193115}],
#  'q15': [{'doc_id': 'doc_008',
#    'title': '청킹 전략',
#    'content': '청킹은 긴 문서를 적절한 크기로 분할하는 전략입니다. 고정 크기 청킹, 의미 기반 청킹, 재귀적 청킹 등의 방법이 있습니다. 청크 크기와 오버랩은 검색 품질에 큰 영향을 미치며, 보통 500-1000 토큰을 사용합니다.',
#    'score': 0.9863953590393066},
#   {'doc_id': 'doc_002',
#    'title': 'RAG 시스템 개요',
#    'content': 'RAG(Retrieval-Augmented Generation)는 검색과 생성을 결합한 기법입니다. 외부 지식 베이스에서 관련 문서를 검색한 후, 이를 컨텍스트로 활용하여 LLM이 답변을 생성합니다. 환각(hallucination)을 줄이고 최신 정보를 반영할 수 있는 장점이 있습니다.',
#    'score': 1.0411611795425415},
#   {'doc_id': 'doc_009',
#    'title': '하이브리드 검색',
#    'content': '하이브리드 검색은 키워드 검색(BM25)과 벡터 검색을 결합한 방식입니다. RRF(Reciprocal Rank Fusion)를 통해 두 검색 결과를 효과적으로 병합합니다. 키워드 매칭의 정확성과 시맨틱 검색의 의미 이해를 동시에 활용합니다.',
#    'score': 1.1576526165008545},
#   {'doc_id': 'doc_003',
#    'title': '벡터 임베딩과 유사도 검색',
#    'content': '벡터 임베딩은 텍스트를 고차원 벡터 공간에 매핑하는 기술입니다. 코사인 유사도를 사용하여 의미적으로 유사한 문서를 검색합니다. FAISS, Pinecone 등의 벡터 데이터베이스가 대규모 검색에 활용됩니다.',
#    'score': 1.3813793659210205},
#   {'doc_id': 'doc_006',
#    'title': '토큰화와 텍스트 전처리',
#    'content': '토큰화는 텍스트를 모델이 처리할 수 있는 단위로 분할하는 과정입니다. BPE(Byte Pair Encoding), WordPiece, SentencePiece 등의 알고리즘이 있습니다. 한국어는 교착어 특성상 형태소 분석 기반 토큰화가 효과적입니다.',
#    'score': 1.4771358966827393}]}

# %%
def hit_rate_at_k(query_id, k):
#     qa_list = [q for q in new_qa if q['query_id'] == query_id]
# #     print(qa_list)
#     qa = qa_list[0] if qa_list else None

    qa = next(q for q in new_qa if q['query_id'] == query_id)
    
    relevant_ids = set(qa['relevant_doc_ids'])
    retrieved = search_results_cache[query_id][:k]
    retrieved_ids = {r['doc_id'] for r in retrieved}
    
    return 1 if relevant_ids & retrieved_ids else 0

def average_hit_rate_at_k(k):
    hits = [hit_rate_at_k(qa['query_id'], k) for qa in new_qa] # hits = [1, 0, 1, 0, ....]
    return sum(hits)/ len(hits)

for qa in new_qa:
    for k in [1, 3, 5]:
        hit = hit_rate_at_k(qa['query_id'], k)
        status = 'hit' if hit else 'miss'
        print(f" {qa['query_id']} (@K = {k}): {status} 정답 : {qa['relevant_doc_ids']}")
        print(f"HR@{k} : {average_hit_rate_at_k(k)}")
# Out:
#  q13 (@K = 1): miss 정답 : ['doc_001']
# HR@1 : 0.3333333333333333
#  q13 (@K = 3): miss 정답 : ['doc_001']
# HR@3 : 0.6666666666666666
#  q13 (@K = 5): hit 정답 : ['doc_001']
# HR@5 : 1.0
#  q14 (@K = 1): miss 정답 : ['doc_005']
# HR@1 : 0.3333333333333333
#  q14 (@K = 3): hit 정답 : ['doc_005']
# HR@3 : 0.6666666666666666
#  q14 (@K = 5): hit 정답 : ['doc_005']
# HR@5 : 1.0
#  q15 (@K = 1): hit 정답 : ['doc_008', 'doc_002']
# HR@1 : 0.3333333333333333
#  q15 (@K = 3): hit 정답 : ['doc_008', 'doc_002']
# HR@3 : 0.6666666666666666
#  q15 (@K = 5): hit 정답 : ['doc_008', 'doc_002']
# HR@5 : 1.0

# %%
# MRR  : Mean R(역수) 1/n Ranking

# %%
# 1 : 1/1  : 1
# 2 : 1/2  : 0.5
# 3 : 1/3  : 0.33
        
# 1/10

# 0.5~ 양호

# %%
def reciprocal_rank(query_id, k):
    qa = next(q for q in qa_dataset if q['query_id'] == query_id)
    relevant_ids = set(qa['relevant_doc_ids'])
    retrieved = search_results_cache[query_id][:k]
#     [0, 1, 2]
    for rank, result in enumerate(retrieved,1):
        if result['doc_id'] in relevant_ids:
            return 1.0 / rank
    
    return 0.0
    

def mean_reciprocal_rank(k):
    rr_score = [reciprocal_rank(qa['query_id'], k) for qa in qa_dataset]
    return sum(rr_score) / len(rr_score)

# %%
mean_reciprocal_rank(k=5)
# Out:
# 1.0

# %%
len(qa_dataset)
# Out:
# 12

# %%
rows = []
for qa in qa_dataset:
    rr = reciprocal_rank(qa['query_id'], 5)
    rows.append({'query_id' : qa['query_id'], 'question' : qa['question'], 'RR@5' : {round(rr, 4)}})

df_rr = pd.DataFrame(rows)
df_rr
# Out:
#    query_id                   question   RR@5
# 0       q01     트랜스포머의 핵심 메커니즘은 무엇인가요?  {1.0}
# 1       q02        RAG 시스템의 장점은 무엇인가요?  {1.0}
# 2       q03   벡터 유사도 검색에 사용되는 데이터베이스는?  {1.0}
# 3       q04        프롬프트 엔지니어링의 주요 기법은?  {1.0}
# 4       q05   효율적 파인튜닝 기법에는 어떤 것이 있나요?  {1.0}
# 5       q06          한국어 토큰화에 적합한 방법은?  {1.0}
# 6       q07       LLM-as-Judge란 무엇인가요?  {1.0}
# 7       q08          적절한 청크 크기는 얼마인가요?  {1.0}
# 8       q09   하이브리드 검색에서 결과를 병합하는 방법은?  {1.0}
# 9       q10  검색과 생성을 결합하여 환각을 줄이는 기법은?  {1.0}
# 10      q11           CLIP 모델의 활용 분야는?  {1.0}
# 11      q12      트랜스포머의 구조는 어떻게 되어있나요?  {1.0}

# %%
# DCG, nDCG

# %%
# q1 : 1, 2, 3, 4, 5  -> dcg : 10 : 1, 2, 3, 6, 7, 4, 5 ...
# q2 : 1, 2, 3        -> dcg : 5

# %%
# 키 : 150cm ~ 200cm                              0~1
# 신발 : 200mm ~ 300mm    -> 20 ~ 30 / 0.2 ~0.3   0~1
# 몸무게 : 40kg  ~ 120kg  -> 40000 ~ 120000       0~1

# %%
# DCG : (rel score) / log(i+1)   : i : 1,2,3,4,5 
# NDCG : DCG / IDCG  (Ideal DCG)

# %%
# 10000000  ->  0 ~ 5 / 0 ~ 2
# 2
# 0

# %%
def dcg_at_k(relevances, k):
    relevances = relevances[:k]
    dcg = 0.0
    for i, rel in enumerate(relevances):
        dcg += rel / np.log2(i+2)
    return dcg

# %%
def ndcg_at_k(query_id, k):
    qa = next(q for q in qa_dataset if q['query_id'] == query_id)
    relevant_ids = set(qa['relevant_doc_ids'])
    retrieved = search_results_cache[query_id][:k]
    
    relevances = [1 if r['doc_id'] in relevant_ids else 0 for r in retrieved]
    dcg = dcg_at_k(relevances, k)
    
    idea_relevances = sorted(relevances, reverse=True)
    total_relevant = len(relevant_ids)
    ideal_relevances = [1] * min(total_relevant, k) + [0] * max(0, k-total_relevant)
    idcg = dcg_at_k(ideal_relevances, k)
    
    if idcg == 0:
        return 0.0
    return dcg/idcg

# %%
def average_ndcg_at_k(k):
    scores = [ndcg_at_k(qa['query_id'],k) for qa in qa_dataset]
    return sum(scores) / len(scores)

# %%
for k in [1, 3, 5]:
    score = average_ndcg_at_k(k)
    print(f"NDCG@{k} : {score}")
# Out:
# NDCG@1 : 1.0
# NDCG@3 : 0.9677622660637882
# NDCG@5 : 0.9897679429448374

# %%
for qa in qa_dataset:
    score = ndcg_at_k(qa['query_id'],5)
    print(f"{qa['query_id']} : NDCG@5 : {score} | 정답 수 = {len(qa['relevant_doc_ids'])}")
# Out:
# q01 : NDCG@5 : 1.0 | 정답 수 = 1
# q02 : NDCG@5 : 1.0 | 정답 수 = 1
# q03 : NDCG@5 : 1.0 | 정답 수 = 1
# q04 : NDCG@5 : 1.0 | 정답 수 = 1
# q05 : NDCG@5 : 1.0 | 정답 수 = 1
# q06 : NDCG@5 : 1.0 | 정답 수 = 1
# q07 : NDCG@5 : 1.0 | 정답 수 = 1
# q08 : NDCG@5 : 1.0 | 정답 수 = 1
# q09 : NDCG@5 : 1.0 | 정답 수 = 1
# q10 : NDCG@5 : 0.8772153153380493 | 정답 수 = 2
# q11 : NDCG@5 : 1.0 | 정답 수 = 1
# q12 : NDCG@5 : 1.0 | 정답 수 = 1

# %%
# Precision Recall

# %%
코로나 
              실제 코로나(양성)     코로나 음성
양성탐지          100                  0
음성탐지           0
